# %% [markdown]
# ## Set up SIMECO

# %% [markdown]
# Clone the repository and install dependencies. It may take 1-2 minutes.

# %%
# %%bash
# git clone https://github.com/complete3d/simeco.git
# # install pointnet2_ops_lib
# cd simeco/extensions/pointnet2_ops_lib && python setup.py install
# # # install required PyPI packages
# cd ../../demo && pip install -r demo_requirements.txt
# # # copy visual.py to root directory
# cd ../..  && cp simeco/demo/visual.py visual.py

# %% [markdown]
# ##  Quick examples

# %% [markdown]
# **Example without transformation**
#
# You can interactively explore the model by dragging it.

# %%
from visual import *
# !python simeco/inference.py --pc_file simeco/demo/demo_data/pc/2a05d684eeb9c1cfae2ca9bb680dd18b.npy
visualize_point_cloud(
    "Incomplete point cloud", "simeco/demo/demo_data/pc/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    "Predicted point cloud", "simeco/demo/demo_data/result/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    eye = dict(x=0, y=0.8, z=0),
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example with rotation transformation**
#
# You can interactively explore the model by dragging it.

# %%
from visual import *
# !python simeco/inference.py --pc_file simeco/demo/demo_data/pc/2a05d684eeb9c1cfae2ca9bb680dd18b.npy --aug_mode rotation
visualize_point_cloud(
    "Incomplete point cloud", "simeco/demo/demo_data/pc_rotation/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    "Predicted point cloud", "simeco/demo/demo_data/result_rotation/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    eye = dict(x=0, y=0.8, z=0),
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example with scale transformation**
#
# You can interactively explore the model by dragging it.

# %%
from visual import *
# !python simeco/inference.py --pc_file simeco/demo/demo_data/pc/2a05d684eeb9c1cfae2ca9bb680dd18b.npy --aug_mode scale
visualize_point_cloud(
    "Incomplete point cloud", "simeco/demo/demo_data/pc_scale/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    "Predicted point cloud", "simeco/demo/demo_data/result_scale/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    eye = dict(x=0, y=0.8, z=0),
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example with translation transformation**
#
# You can interactively explore the model by dragging it.

# %%
from visual import *
# !python simeco/inference.py --pc_file simeco/demo/demo_data/pc/2a05d684eeb9c1cfae2ca9bb680dd18b.npy --aug_mode translation
visualize_point_cloud(
    "Incomplete point cloud", "simeco/demo/demo_data/pc_translation/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    "Predicted point cloud", "simeco/demo/demo_data/result_translation/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    eye = dict(x=0, y=0.8, z=0),
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example with SIM(3) transformation**
#
# You can interactively explore the model by dragging it.

# %%
from visual import *
# !python simeco/inference.py --pc_file simeco/demo/demo_data/pc/2a05d684eeb9c1cfae2ca9bb680dd18b.npy --aug_mode sim3
visualize_point_cloud(
    "Incomplete point cloud", "simeco/demo/demo_data/pc_sim3/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    "Predicted point cloud", "simeco/demo/demo_data/result_sim3/2a05d684eeb9c1cfae2ca9bb680dd18b.npy",
    eye = dict(x=0, y=0.8, z=0),
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
